# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, FloatType, IntegerType
from pyspark.sql.functions import col, to_date, dayofmonth, dayofweek, month, when, lit, isnull, count
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler, Imputer
from pyspark.ml.classification import RandomForestClassifier, LogisticRegression, GBTClassifier, DecisionTreeClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml import Pipeline
from datetime import datetime
import time
import pandas as pd
import numpy as np

# Initialize Spark Session optimized for local Jupyter execution
spark = SparkSession.builder \
    .appName("FraudDetection") \
    .master("local[*]") \
    .config("spark.sql.debug.maxToStringFields", "100") \
    .config("spark.driver.memory", "8g") \
    .config("spark.executor.memory", "8g") \
    .config("spark.driver.maxResultSize", "4g") \
    .getOrCreate()

print("Spark session created successfully!")

# Define schema
schema = StructType([
    StructField("Transaction ID", StringType(), True),
    StructField("Customer ID", StringType(), True),
    StructField("Transaction Amount", FloatType(), True),
    StructField("Transaction Date", StringType(), True),
    StructField("Payment Method", StringType(), True),
    StructField("Product Category", StringType(), True),
    StructField("Quantity", IntegerType(), True),
    StructField("Customer Age", IntegerType(), True),
    StructField("Customer Location", StringType(), True),
    StructField("Device Used", StringType(), True),
    StructField("IP Address", StringType(), True),
    StructField("Shipping Address", StringType(), True),
    StructField("Billing Address", StringType(), True),
    StructField("Is Fraudulent", IntegerType(), True),
    StructField("Account Age Days", IntegerType(), True),
    StructField("Transaction Hour", IntegerType(), True)
])

# Load data with error handling
try:
    # For local Jupyter environment, use local file path - adjust this to your file location
    try:
        # First try local file
        file_path = "transaction_data.csv"  # Change this to your local file path
        df = spark.read.option("header", "true") \
                     .option("multiLine", "true") \
                     .schema(schema) \
                     .csv(file_path)
    except:
        # If local fails, try HDFS path
        today = datetime.today()
        hdfs_path = f"hdfs://namenode:9000/user/root/transactions/YYYY={today.year}/MM={today.month:02d}/DD={today.day:02d}/transaction_data.csv"
        df = spark.read.option("header", "true") \
                     .option("multiLine", "true") \
                     .schema(schema) \
                     .csv(hdfs_path)
    
    print("Data loaded successfully. Row count:", df.count())
except Exception as e:
    print(f"Error loading data: {str(e)}")
    print("Please update the file path to point to your transaction data.")
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/20 19:35:49 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/04/20 19:35:50 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# Spark session created successfully!
# [Stage 0:>                                                          (0 + 1) / 1]
# Data loaded successfully. Row count: 23634

# %%
# Data Quality Check
print("\nData Quality Check:")
print("Null values per column:")
null_counts = df.select([count(when(isnull(c), c)).alias(c) for c in df.columns])
null_counts.show(vertical=True)

# Show sample data
print("\nSample data:")
df.show(5)

# Check class distribution
fraud_count = df.filter(col("Is Fraudulent") == 1).count()
non_fraud_count = df.filter(col("Is Fraudulent") == 0).count()
total = fraud_count + non_fraud_count
fraud_ratio = fraud_count / total

print(f"\nFraudulent transactions: {fraud_count} ({fraud_ratio:.2%})")
print(f"Non-fraudulent transactions: {non_fraud_count} ({1-fraud_ratio:.2%})")
print(f"Imbalance ratio: 1:{non_fraud_count/fraud_count:.1f}")

# Data Preprocessing
print("\nStarting Data Preprocessing...")
start_time = time.time()

# Convert Transaction Date and extract features
df = df.withColumn("Transaction Date", to_date(col("Transaction Date")))
df = df.withColumn("DayOfMonth", dayofmonth(col("Transaction Date")))
df = df.withColumn("DayOfWeek", dayofweek(col("Transaction Date")))
df = df.withColumn("Month", month(col("Transaction Date")))

# Create feature: is shipping different from billing
df = df.withColumn("AddressMismatch", 
                 when(col("Shipping Address") != col("Billing Address"), 1).otherwise(0))

# Create feature: transaction amount per quantity
df = df.withColumn("AmountPerQuantity", 
                 when(col("Quantity") > 0, col("Transaction Amount") / col("Quantity")).otherwise(col("Transaction Amount")))

# Create time-based features
df = df.withColumn("IsWeekend", 
                 when((col("DayOfWeek") == 1) | (col("DayOfWeek") == 7), 1).otherwise(0))

df = df.withColumn("IsNightTime", 
                 when((col("Transaction Hour") >= 22) | (col("Transaction Hour") <= 5), 1).otherwise(0))

# Calculate class weights (to handle imbalance)
# Higher weight for minority class (fraud)
weight_multiplier = 5.0  # Increase this for better fraud detection
fraud_weight = (non_fraud_count / total) * weight_multiplier
non_fraud_weight = (fraud_count / total)

df = df.withColumn("classWeight", 
                 when(col("Is Fraudulent") == 1, fraud_weight)
                 .otherwise(non_fraud_weight))

# Fill nulls in categorical columns
categorical_cols = ["Payment Method", "Product Category", "Customer Location", "Device Used"]
for col_name in categorical_cols:
    df = df.fillna("unknown", subset=[col_name])

# Define numerical columns for imputation
numerical_cols = ["Transaction Amount", "Quantity", "Customer Age", 
                 "Account Age Days", "Transaction Hour", "DayOfMonth", 
                 "DayOfWeek", "Month", "AddressMismatch", "AmountPerQuantity",
                 "IsWeekend", "IsNightTime"]

print(f"\nPreprocessing completed in {time.time() - start_time:.2f} seconds")
print("Sample of weights (fraud cases should have higher weight):")
df.select("Is Fraudulent", "classWeight").distinct().orderBy("Is Fraudulent").show(5)

# Show all features
print("\nAll features after preprocessing:")
df.printSchema()
# Out:
# Data Quality Check:
# Null values per column:
# -RECORD 0-----------------
#  Transaction ID     | 0
#  Customer ID        | 0
#  Transaction Amount | 0
#  Transaction Date   | 0
#  Payment Method     | 0
#  Product Category   | 0
#  Quantity           | 0
#  Customer Age       | 0
#  Customer Location  | 0
#  Device Used        | 0
#  IP Address         | 0
#  Shipping Address   | 0
#  Billing Address    | 0
#  Is Fraudulent      | 0
#  Account Age Days   | 0
#  Transaction Hour   | 0
#
#
# Sample data:
# +--------------------+--------------------+------------------+-------------------+--------------+----------------+--------+------------+-------------------+-----------+---------------+--------------------+--------------------+-------------+----------------+----------------+
# |      Transaction ID|         Customer ID|Transaction Amount|   Transaction Date|Payment Method|Product Category|Quantity|Customer Age|  Customer Location|Device Used|     IP Address|    Shipping Address|     Billing Address|Is Fraudulent|Account Age Days|Transaction Hour|
# +--------------------+--------------------+------------------+-------------------+--------------+----------------+--------+------------+-------------------+-----------+---------------+--------------------+--------------------+-------------+----------------+----------------+
# |c12e07a0-8a06-4c0...|8ca9f102-02a4-420...|             42.32|2024-03-24 23:42:43|        PayPal|     electronics|       1|          40|    East Jameshaven|    desktop|  110.87.246.85|5399 Rachel Strav...|5399 Rachel Strav...|            0|             282|              23|
# |7d187603-7961-4fc...|4d158416-caae-4b0...|            301.34|2024-01-22 00:53:31|   credit card|     electronics|       3|          35|           Kingstad|     tablet|  14.73.104.153|5230 Stephanie Fo...|5230 Stephanie Fo...|            0|             223|               0|
# |f2c14f9d-92df-4aa...|ccae47b8-75c7-4f5...|            340.32|2024-01-22 08:06:03|    debit card|    toys & games|       5|          29|         North Ryan|    desktop|    67.58.94.93|195 Cole Oval\nPo...|4772 David Strave...|            0|             360|               8|
# |e9949bfa-194d-486...|b04960c0-aeee-490...|             95.77|2024-01-16 20:34:53|   credit card|     electronics|       5|          45|         Kaylaville|     mobile|202.122.126.216|7609 Cynthia Squa...|7609 Cynthia Squa...|            0|             325|              20|
# |7362837c-7538-434...|de9d6351-b3a7-4bc...|             77.45|2024-01-16 15:47:23|   credit card|        clothing|       5|          42|North Edwardborough|    desktop|   96.77.232.76|2494 Robert Ramp ...|2494 Robert Ramp ...|            0|             116|              15|
# +--------------------+--------------------+------------------+-------------------+--------------+----------------+--------+------------+-------------------+-----------+---------------+--------------------+--------------------+-------------+----------------+----------------+
# only showing top 5 rows
#
#
# Fraudulent transactions: 1222 (5.17%)
# Non-fraudulent transactions: 22412 (94.83%)
# Imbalance ratio: 1:18.3
#
# Starting Data Preprocessing...
#
# Preprocessing completed in 0.33 seconds
# Sample of weights (fraud cases should have higher weight):
# +-------------+------------------+
# |Is Fraudulent|       classWeight|
# +-------------+------------------+
# |            0|0.0517051705170517|
# |            1| 4.741474147414742|
# +-------------+------------------+
#
#
# All features after preprocessing:
# root
#  |-- Transaction ID: string (nullable = true)
#  |-- Customer ID: string (nullable = true)
#  |-- Transaction Amount: float (nullable = true)
#  |-- Transaction Date: date (nullable = true)
#  |-- Payment Method: string (nullable = false)
#  |-- Product Category: string (nullable = false)
#  |-- Quantity: integer (nullable = true)
#  |-- Customer Age: integer (nullable = true)
#  |-- Customer Location: string (nullable = false)
#  |-- Device Used: string (nullable = false)
#  |-- IP Address: string (nullable = true)
#  |-- Shipping Address: string (nullable = true)
#  |-- Billing Address: string (nullable = true)
#  |-- Is Fraudulent: integer (nullable = true)
#  |-- Account Age Days: integer (nullable = true)
#  |-- Transaction Hour: integer (nullable = true)
#  |-- DayOfMonth: integer (nullable = true)
#  |-- DayOfWeek: integer (nullable = true)
#  |-- Month: integer (nullable = true)
#  |-- AddressMismatch: integer (nullable = false)
#  |-- AmountPerQuantity: double (nullable = true)
#  |-- IsWeekend: integer (nullable = false)
#  |-- IsNightTime: integer (nullable = false)
#  |-- classWeight: double (nullable = false)

# %%
# Define preprocessing pipeline stages (without the classifier)
preprocessing_stages = []

# 1. Categorical encoding
categorical_cols = ["Payment Method", "Product Category", "Customer Location", "Device Used"]
categorical_features = []

for col_name in categorical_cols:
    # Convert strings to numerical indices
    string_indexer = StringIndexer(inputCol=col_name, outputCol=f"{col_name}_Index", handleInvalid="keep")
    preprocessing_stages.append(string_indexer)
    
    # One-hot encode indices
    encoder = OneHotEncoder(inputCols=[f"{col_name}_Index"], outputCols=[f"{col_name}_OHE"], handleInvalid="keep")
    preprocessing_stages.append(encoder)
    categorical_features.append(f"{col_name}_OHE")

# 2. Numerical columns (impute missing values with median)
numerical_features = []
for num_col in numerical_cols:
    imputer = Imputer(inputCol=num_col, outputCol=f"{num_col}_imputed", strategy="median")
    preprocessing_stages.append(imputer)
    numerical_features.append(f"{num_col}_imputed")

# 3. Assemble all features into a vector
assembler = VectorAssembler(inputCols=categorical_features + numerical_features, 
                           outputCol="rawFeatures", 
                           handleInvalid="keep")
preprocessing_stages.append(assembler)

# 4. Scale features (mean=0, std=1)
scaler = StandardScaler(inputCol="rawFeatures", outputCol="features", withStd=True, withMean=True)
preprocessing_stages.append(scaler)

print("Feature pipeline built with stages:")
for i, stage in enumerate(preprocessing_stages):
    print(f"{i+1}. {type(stage).__name__}")

# Create preprocessing pipeline
preprocessing_pipeline = Pipeline(stages=preprocessing_stages)
# Out:
# Feature pipeline built with stages:
# 1. StringIndexer
# 2. OneHotEncoder
# 3. StringIndexer
# 4. OneHotEncoder
# 5. StringIndexer
# 6. OneHotEncoder
# 7. StringIndexer
# 8. OneHotEncoder
# 9. Imputer
# 10. Imputer
# 11. Imputer
# 12. Imputer
# 13. Imputer
# 14. Imputer
# 15. Imputer
# 16. Imputer
# 17. Imputer
# 18. Imputer
# 19. Imputer
# 20. Imputer
# 21. VectorAssembler
# 22. StandardScaler

# %%
# Split data (80% train, 20% test)
train, test = df.randomSplit([0.8, 0.2], seed=42)

# Check class distribution in splits
train_fraud_ratio = train.filter(col("Is Fraudulent") == 1).count() / train.count()
test_fraud_ratio = test.filter(col("Is Fraudulent") == 1).count() / test.count()
print(f"Train fraud ratio: {train_fraud_ratio:.2%}")
print(f"Test fraud ratio: {test_fraud_ratio:.2%}")

# Remove any conflicting columns if they exist
columns_to_check = ["prediction", "rawFeatures", "features"] + [f"{c}_Index" for c in categorical_cols] + [f"{c}_OHE" for c in categorical_cols] + [f"{c}_imputed" for c in numerical_cols]
for column in columns_to_check:
    if column in train.columns:
        train = train.drop(column)
    if column in test.columns:
        test = test.drop(column)

# Apply preprocessing to get a consistent dataset
print("\nApplying preprocessing pipeline...")
preprocessor_model = preprocessing_pipeline.fit(train)
train_preprocessed = preprocessor_model.transform(train)
test_preprocessed = preprocessor_model.transform(test)

# Define parameter combinations for Random Forest
rf_params = [
    {"numTrees": 50, "maxDepth": 5, "minInstancesPerNode": 1, "impurity": "gini"},
    {"numTrees": 100, "maxDepth": 10, "minInstancesPerNode": 2, "impurity": "entropy"},
    {"numTrees": 200, "maxDepth": 15, "minInstancesPerNode": 4, "impurity": "gini"}
]

rf_results = []
evaluator = BinaryClassificationEvaluator(labelCol="Is Fraudulent", metricName="areaUnderROC")
print("\nTraining Random Forest with multiple parameter combinations...")

for params in rf_params:
    start_time = time.time()
    
    # Create Random Forest with specific parameters
    rf = RandomForestClassifier(
        featuresCol="features", 
        labelCol="Is Fraudulent", 
        weightCol="classWeight",
        **params
    )
    
    try:
        # Train model directly on preprocessed data
        rf_model = rf.fit(train_preprocessed)
        
        # Make predictions
        predictions = rf_model.transform(test_preprocessed)
        
        # Evaluate
        auc = evaluator.evaluate(predictions)
        recall_eval = MulticlassClassificationEvaluator(
            labelCol="Is Fraudulent", 
            metricName="weightedRecall"
        )
        recall = recall_eval.evaluate(predictions)
        
        training_time = time.time() - start_time
        
        # Store results
        rf_results.append({
            "numTrees": params["numTrees"],
            "maxDepth": params["maxDepth"],
            "minInstancesPerNode": params["minInstancesPerNode"],
            "impurity": params["impurity"],
            "AUC": auc,
            "Recall": recall,
            "Time": training_time,
            "Model": rf_model  # Store the model itself for later use
        })
        
        print(f"RF with {params} - AUC: {auc:.4f}, Recall: {recall:.4f}, Time: {training_time:.1f}s")
    
    except Exception as e:
        print(f"Error during training with {params}: {str(e)}")

# Check if any models were successfully trained
if not rf_results:
    print("\nNo models were successfully trained. Please check the pipeline and data.")
else:
    # Find best model
    best_rf_params = max(rf_results, key=lambda x: x["AUC"])
    print("\nBest Random Forest parameters:")
    print(f"Number of trees: {best_rf_params['numTrees']}")
    print(f"Max depth: {best_rf_params['maxDepth']}")
    print(f"Min instances per node: {best_rf_params['minInstancesPerNode']}")
    print(f"Impurity: {best_rf_params['impurity']}")
    print(f"AUC: {best_rf_params['AUC']:.4f}")
    print(f"Recall: {best_rf_params['Recall']:.4f}")
    
    # Save best model for comparison
    best_rf_model = best_rf_params["Model"]
# Out:
# Train fraud ratio: 5.30%
# Test fraud ratio: 4.66%
#
# Applying preprocessing pipeline...
# 25/04/20 19:37:34 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 25/04/20 19:37:31 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# Training Random Forest with multiple parameter combinations...
# 25/04/20 19:37:34 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:37:34 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:37:38 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 19:38:25 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:38:28 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:38:30 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:38:32 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:38:33 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:38:36 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 19:38:37 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# RF with {'numTrees': 50, 'maxDepth': 5, 'minInstancesPerNode': 1, 'impurity': 'gini'} - AUC: 0.7171, Recall: 0.0466, Time: 64.6s
# 25/04/20 19:38:38 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:38:38 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:38:40 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 19:39:26 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:39:32 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:39:35 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:39:38 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:39:40 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:39:43 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:39:46 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:39:49 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:39:50 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 19:39:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 19:39:56 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:39:58 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# RF with {'numTrees': 100, 'maxDepth': 10, 'minInstancesPerNode': 2, 'impurity': 'entropy'} - AUC: 0.7791, Recall: 0.0466, Time: 80.9s
# 25/04/20 19:39:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:39:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:40:01 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 19:40:47 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:40:55 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:41:00 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:41:05 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:41:09 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 19:41:14 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 19:41:17 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 19:41:22 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/04/20 19:41:27 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/04/20 19:41:32 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/04/20 19:41:37 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/04/20 19:41:41 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/04/20 19:41:46 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/04/20 19:41:51 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/04/20 19:41:57 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/04/20 19:42:03 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/04/20 19:42:04 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# RF with {'numTrees': 200, 'maxDepth': 15, 'minInstancesPerNode': 4, 'impurity': 'gini'} - AUC: 0.7797, Recall: 0.0466, Time: 126.4s
#
# Best Random Forest parameters:
# Number of trees: 200
# Max depth: 15
# Min instances per node: 4
# Impurity: gini
# AUC: 0.7797
# Recall: 0.0466

# %%
# Define models to test
try:
    # Only proceed if we have a best RF model from previous step
    models = {
        "Logistic Regression": LogisticRegression(
            featuresCol="features", 
            labelCol="Is Fraudulent", 
            weightCol="classWeight",
            maxIter=20,
            regParam=0.01,
            elasticNetParam=0.5
        ),
        "Random Forest": RandomForestClassifier(
            featuresCol="features", 
            labelCol="Is Fraudulent", 
            weightCol="classWeight",
            numTrees=best_rf_params["numTrees"],
            maxDepth=best_rf_params["maxDepth"],
            minInstancesPerNode=best_rf_params["minInstancesPerNode"],
            impurity=best_rf_params["impurity"]
        ),
        "Gradient-Boosted Trees": GBTClassifier(
            featuresCol="features", 
            labelCol="Is Fraudulent", 
            weightCol="classWeight",
            maxIter=50,
            maxDepth=8,
            stepSize=0.1
        ),
        "Decision Tree": DecisionTreeClassifier(
            featuresCol="features", 
            labelCol="Is Fraudulent", 
            weightCol="classWeight",
            maxDepth=10,
            impurity="entropy"
        )
    }

    # Metrics to evaluate
    metrics = {
        "AUC": BinaryClassificationEvaluator(labelCol="Is Fraudulent", metricName="areaUnderROC"),
        "PR AUC": BinaryClassificationEvaluator(labelCol="Is Fraudulent", metricName="areaUnderPR"),
        "Recall": MulticlassClassificationEvaluator(labelCol="Is Fraudulent", metricName="weightedRecall"),
        "Precision": MulticlassClassificationEvaluator(labelCol="Is Fraudulent", metricName="weightedPrecision"),
        "F1": MulticlassClassificationEvaluator(labelCol="Is Fraudulent", metricName="f1")
    }

    results = []

    # Train and evaluate each model
    for model_name, model in models.items():
        print(f"\nTraining {model_name}...")
        start_time = time.time()
        
        try:
            # Train model directly on preprocessed data
            trained_model = model.fit(train_preprocessed)
            predictions = trained_model.transform(test_preprocessed)
            
            # Evaluate with all metrics
            model_results = {"Model": model_name}
            for metric_name, evaluator in metrics.items():
                score = evaluator.evaluate(predictions)
                model_results[metric_name] = score
            
            training_time = time.time() - start_time
            model_results["Time (s)"] = training_time
            
            results.append(model_results)
            
            # Print model performance
            print(f"{model_name} evaluation:")
            for metric, value in model_results.items():
                if metric != "Model" and metric != "Time (s)":
                    print(f"  - {metric}: {value:.4f}")
            print(f"  - Training time: {training_time:.1f}s")
        
        except Exception as e:
            print(f"Error training {model_name}: {str(e)}")

    # Show results table if we have any
    if results:
        results_df = spark.createDataFrame(results).orderBy("F1", ascending=False)
        print("\nModel Performance Comparison:")
        results_df.show(truncate=False)
        
        # Convert to pandas for visualization (if you want to plot the results)
        results_pd = results_df.toPandas()
        print("Results converted to pandas DataFrame for visualization")
    else:
        print("No models were successfully trained for comparison")

except Exception as e:
    print(f"Error in model comparison step: {str(e)}")
    print("Make sure parameter tuning step completed successfully")
# Out:
# Training Logistic Regression...
# 25/04/20 19:47:28 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:38 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 25/04/20 19:47:38 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
# 25/04/20 19:47:38 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:47 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:48 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:49 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:49 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:50 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:50 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:51 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:51 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:52 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:53 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:53 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:54 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:54 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:55 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:55 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:56 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:57 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:57 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:58 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:58 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:47:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:00 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:01 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:02 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:05 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:06 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:07 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# Logistic Regression evaluation:
#   - AUC: 0.7817
#   - PR AUC: 0.2915
#   - Recall: 0.3684
#   - Precision: 0.9441
#   - F1: 0.4898
#   - Training time: 40.2s
#
# Training Random Forest...
# 25/04/20 19:48:08 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:08 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:48:08 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 19:49:04 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:49:19 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:49:24 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:49:30 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:49:34 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 19:49:39 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 19:49:45 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 19:49:50 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/04/20 19:49:56 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/04/20 19:49:59 WARN DAGScheduler: Broadcasting large task binary with size 3.5 MiB
# 25/04/20 19:50:05 WARN DAGScheduler: Broadcasting large task binary with size 3.6 MiB
# 25/04/20 19:50:12 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/04/20 19:50:19 WARN DAGScheduler: Broadcasting large task binary with size 3.7 MiB
# 25/04/20 19:50:26 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/04/20 19:50:30 WARN DAGScheduler: Broadcasting large task binary with size 3.8 MiB
# 25/04/20 19:50:36 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/04/20 19:50:37 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/04/20 19:50:38 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/04/20 19:50:39 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# 25/04/20 19:50:39 WARN DAGScheduler: Broadcasting large task binary with size 3.4 MiB
# Random Forest evaluation:
#   - AUC: 0.7797
#   - PR AUC: 0.2603
#   - Recall: 0.0466
#   - Precision: 0.0022
#   - F1: 0.0042
#   - Training time: 152.6s
#
# Training Gradient-Boosted Trees...
# 25/04/20 19:50:41 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:50:41 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 19:50:43 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 19:51:37 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:51:46 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:51:48 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:51:52 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:51:52 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:51:54 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:51:57 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:00 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:03 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:06 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:08 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:11 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:14 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:17 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:17 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 19:52:20 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:23 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:26 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:28 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:31 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:33 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:36 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:39 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:44 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:48 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:47 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:49 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:52 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:54 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:52:57 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:00 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:03 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:06 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:09 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:11 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:14 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:14 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:17 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:20 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:23 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:26 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:28 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:31 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:33 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:36 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:39 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:42 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:44 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:47 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:49 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:51 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:54 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:56 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:53:59 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:54:02 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:54:04 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:54:07 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:54:09 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:54:09 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:54:11 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 19:54:14 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:17 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:19 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:21 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:24 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:26 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:29 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:31 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:33 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:36 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:36 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:39 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:41 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:43 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:46 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:48 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:50 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:53 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:55 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:54:58 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:00 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:03 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:06 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:05 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:08 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:10 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:13 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:15 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:17 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:20 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:22 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:25 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:27 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:30 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:32 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:32 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:34 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:37 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:39 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:42 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:47 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:49 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:52 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:54 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:56 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:55:59 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:02 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:05 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:07 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:10 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:12 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:14 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:17 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:19 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:22 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:24 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:27 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:30 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:30 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:32 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:34 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:37 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:39 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 19:56:42 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:44 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:47 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:49 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:51 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:54 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:56:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:02 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:04 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:06 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:08 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:10 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:13 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:15 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:18 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:21 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:23 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:26 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:27 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:29 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:32 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:34 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:36 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:38 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:41 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:43 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:45 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:47 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:50 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:52 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:54 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:57:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:01 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:03 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:05 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:07 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:10 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:12 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:14 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:17 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:19 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:21 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:22 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:24 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:26 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:29 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:31 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:33 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:35 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:38 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:40 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:42 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:45 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:47 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:50 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:52 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:53 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:58:58 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 19:59:01 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:03 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:06 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:08 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:11 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:13 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:15 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:18 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:20 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:21 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:23 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:26 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:28 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:31 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:33 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:36 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:38 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:40 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:43 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:46 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:48 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:48 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:51 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:53 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:55 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 19:59:58 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:00 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:03 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:05 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:08 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:10 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:12 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:15 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:15 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:18 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:20 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:22 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:25 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:27 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:29 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:32 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:34 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:37 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:39 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:42 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:44 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:44 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:47 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:49 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:51 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:54 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:56 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:00:59 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:01 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:03 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:06 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:08 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:10 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:10 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:13 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:15 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:18 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:20 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:22 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:25 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:27 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:30 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:32 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:34 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:01:37 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:39 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:39 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:42 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:44 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:47 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:49 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:51 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:54 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:56 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:01:59 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:01 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:03 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:06 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:06 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:08 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:11 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:13 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:16 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:18 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:20 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:23 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:26 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:28 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:30 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:33 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:35 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:35 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:38 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:40 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:43 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:45 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:47 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:50 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:52 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:54 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:57 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:02:59 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:02 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:02 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:04 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:07 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:09 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:12 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:14 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:16 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:19 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:21 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:24 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:26 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:28 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:31 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:31 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:33 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:36 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:38 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:41 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:43 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:46 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:48 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:50 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:56 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:58 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:03:58 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:01 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:03 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:06 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:08 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:11 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:14 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:16 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:19 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:21 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:23 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:26 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:26 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:28 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:31 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:33 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:36 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:38 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:41 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:43 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:46 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:48 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:51 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:54 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:56 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:04:58 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:05:01 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:05:03 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:06 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:09 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:11 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:14 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:16 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:19 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:21 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:21 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:24 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:26 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:29 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:31 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:33 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:36 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:38 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:40 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:43 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:45 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:48 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:48 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:50 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:53 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:55 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:05:58 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:00 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:02 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:05 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:07 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:09 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:12 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:14 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:16 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:17 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:19 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:21 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:24 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:26 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:28 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:31 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:33 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:36 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:38 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:40 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:43 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:43 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:45 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:48 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:50 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:53 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:06:55 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:06:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:06:57 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:06:57 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:06:58 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# Gradient-Boosted Trees evaluation:
#   - AUC: 0.7452
#   - PR AUC: 0.3432
#   - Recall: 0.6596
#   - Precision: 0.9375
#   - F1: 0.7573
#   - Training time: 978.2s
#
# Training Decision Tree...
# 25/04/20 20:06:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:06:59 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:07:01 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 20:07:48 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:07:53 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:07:56 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:07:58 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:08:01 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:08:03 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:08:05 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:08:06 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:08:08 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:08:10 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:08:13 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:08:14 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:08:14 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:08:15 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:08:15 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# Decision Tree evaluation:
#   - AUC: 0.5856
#   - PR AUC: 0.1181
#   - Recall: 0.4833
#   - Precision: 0.9254
#   - F1: 0.6115
#   - Training time: 77.4s
#
# Model Performance Comparison:
# +------------------+-------------------+----------------------+-------------------+--------------------+-------------------+-----------------+
# |AUC               |F1                 |Model                 |PR AUC             |Precision           |Recall             |Time (s)         |
# +------------------+-------------------+----------------------+-------------------+--------------------+-------------------+-----------------+
# |0.7451786652653702|0.7572958081084157 |Gradient-Boosted Trees|0.34315477559817115|0.9374502246353624  |0.6596015260703688 |978.1850979328156|
# |0.5855653017502728|0.6115360455555233 |Decision Tree         |0.11814795945223107|0.9253916354037492  |0.48325561678677403|77.37584209442139|
# |0.7816686203969474|0.48975980455963225|Logistic Regression   |0.29146732606134446|0.9440829498593696  |0.36837643069097076|40.21971654891968|
# |0.7796657100125286|0.00415495510158951|Random Forest         |0.2603105106423401 |0.002174350179276071|0.04662992793556592|152.6174280643463|
# +------------------+-------------------+----------------------+-------------------+--------------------+-------------------+-----------------+
#
# Results converted to pandas DataFrame for visualization

# %%
# Determine the best model based on F1 score from results_df
try:
    # If we have valid results
    if results and not results_df.isEmpty():
        # Get the best model by F1 score
        best_model_row = results_df.first()
        best_model_name = best_model_row["Model"]
        
        print(f"\nThe best performing model is: {best_model_name}")
        print(f"F1 Score: {best_model_row['F1']:.4f}")
        print(f"AUC: {best_model_row['AUC']:.4f}")
        print(f"PR AUC: {best_model_row['PR AUC']:.4f}")
        print(f"Precision: {best_model_row['Precision']:.4f}")
        print(f"Recall: {best_model_row['Recall']:.4f}")
        
        # Get the trained model object (assuming it's stored in the variable named according to the model name)
        best_model = None
        if best_model_name == "Gradient-Boosted Trees":
            best_model = models["Gradient-Boosted Trees"].fit(train_preprocessed)
        elif best_model_name == "Random Forest":
            best_model = models["Random Forest"].fit(train_preprocessed)
        elif best_model_name == "Logistic Regression":
            best_model = models["Logistic Regression"].fit(train_preprocessed)
        elif best_model_name == "Decision Tree":
            best_model = models["Decision Tree"].fit(train_preprocessed)
        
        if best_model:
            # Generate HDFS path for model saving
            from datetime import datetime
            today = datetime.today()
            year = today.year
            month = f"{today.month:02d}"
            day = f"{today.day:02d}"
            base_path = "hdfs://namenode:9000/user/root/model"
            date_path = f"YYYY={year}/MM={month}/DD={day}"
            model_path = f"{base_path}/fraud_detection/{date_path}/{best_model_name.replace(' ', '_').lower()}"
            
            # Save the model to HDFS
            try:
                print(f"\nSaving {best_model_name} model to HDFS at: {model_path}")
                best_model.write().overwrite().save(model_path)
                print(f"Model successfully saved!")
                
                # Save model metadata as JSON for reference
                from pyspark.sql.functions import lit, to_json, struct
                
                # Create metadata DataFrame with model metrics and details
                metadata = spark.createDataFrame([{
                    "model_name": best_model_name,
                    "training_date": today.strftime("%Y-%m-%d"),
                    "metrics": {
                        "f1": float(best_model_row["F1"]),
                        "auc": float(best_model_row["AUC"]),
                        "pr_auc": float(best_model_row["PR AUC"]),
                        "precision": float(best_model_row["Precision"]),
                        "recall": float(best_model_row["Recall"]),
                        "training_time_seconds": float(best_model_row["Time (s)"])
                    }
                }])
                
                # Save metadata alongside model
                metadata_path = f"{model_path}_metadata"
                metadata.write.mode("overwrite").json(metadata_path)
                print(f"Model metadata saved to: {metadata_path}")
                
            except Exception as e:
                print(f"Error saving model to HDFS: {str(e)}")
        else:
            print(f"Could not retrieve the trained {best_model_name} model for saving.")
    else:
        print("No valid model results available to determine the best model.")
        
except Exception as e:
    print(f"Error in selecting and saving the best model: {str(e)}")
# Out:
# The best performing model is: Gradient-Boosted Trees
# F1 Score: 0.7573
# AUC: 0.7452
# PR AUC: 0.3432
# Precision: 0.9375
# Recall: 0.6596
# 25/04/20 20:26:46 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:26:46 WARN DAGScheduler: Broadcasting large task binary with size 2.5 MiB
# 25/04/20 20:26:49 WARN DAGScheduler: Broadcasting large task binary with size 2.6 MiB
# 25/04/20 20:27:41 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:27:49 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:27:51 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:27:54 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:27:56 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:27:57 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:00 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:02 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:05 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:07 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:10 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:13 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:15 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:19 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:21 WARN DAGScheduler: Broadcasting large task binary with size 2.7 MiB
# 25/04/20 20:28:24 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:25 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:27 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:30 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:33 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:35 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:38 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:41 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:44 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:47 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:49 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:51 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:54 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:54 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:28:57 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:00 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:02 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:05 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:08 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:10 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:13 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:15 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:18 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:21 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:21 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:24 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:26 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:29 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:32 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:34 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:37 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:39 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:42 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:45 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:47 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:48 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:50 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:52 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:55 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:29:58 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:00 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:03 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:06 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:09 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:11 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:14 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:16 WARN DAGScheduler: Broadcasting large task binary with size 2.8 MiB
# 25/04/20 20:30:17 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:20 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:22 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:25 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:28 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:30 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:33 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:35 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:38 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:41 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:46 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:49 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:51 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:54 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:57 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:30:59 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:02 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:04 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:07 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:10 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:12 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:13 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:16 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:19 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:24 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:27 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:30 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:33 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:37 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:40 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:41 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:45 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:50 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:54 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:31:57 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:00 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:03 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:07 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:07 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:10 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:13 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:16 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:19 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:22 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:24 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:27 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:30 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:33 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:35 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:36 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:39 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:41 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:44 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:47 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:50 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:52 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:55 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:32:58 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:33:00 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:33:03 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:33:03 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:33:06 WARN DAGScheduler: Broadcasting large task binary with size 2.9 MiB
# 25/04/20 20:33:09 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:12 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:15 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:17 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:22 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:25 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:27 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:30 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:31 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:33 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:36 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:38 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:41 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:43 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:46 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:48 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:51 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:54 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:57 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:33:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:02 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:04 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:07 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:10 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:12 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:15 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:17 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:20 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:22 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:25 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:25 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:28 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:30 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:33 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:35 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:38 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:40 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:43 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:45 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:48 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:51 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:53 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:53 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:56 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:34:59 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:01 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:04 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:07 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:09 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:12 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:14 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:17 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:19 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:23 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:22 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:25 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:27 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:30 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:32 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:35 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:37 WARN DAGScheduler: Broadcasting large task binary with size 3.0 MiB
# 25/04/20 20:35:40 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:35:43 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:35:45 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:35:48 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:35:48 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:35:51 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:35:54 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:35:57 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:00 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:03 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:06 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:09 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:12 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:14 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:17 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:17 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:20 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:23 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:26 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:29 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:32 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:34 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:37 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:40 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:43 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:43 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:47 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:50 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:52 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:55 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:36:58 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:01 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:03 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:06 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:09 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:11 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:12 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:14 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:17 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:19 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:22 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:25 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:28 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:30 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:33 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:36 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:39 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:39 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:41 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:44 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:46 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:49 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:52 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:54 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:37:57 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:00 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:02 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:05 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:08 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:08 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:11 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:13 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:16 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:18 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:21 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:23 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:26 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:29 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:31 WARN DAGScheduler: Broadcasting large task binary with size 3.1 MiB
# 25/04/20 20:38:33 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:37 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:36 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:39 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:41 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:44 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:47 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:49 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:52 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:55 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:38:57 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:00 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:02 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:03 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:05 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:08 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:10 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:13 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:15 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:18 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:20 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:23 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:25 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:28 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:31 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:31 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:33 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:36 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:38 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:41 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:44 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:47 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:50 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:56 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:59 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:39:59 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:03 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:07 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:10 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:13 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:16 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:19 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:22 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:25 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:26 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:29 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:31 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:34 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:36 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:39 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:42 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:44 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:47 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:50 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:52 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:53 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:55 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:40:58 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:01 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:03 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:06 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:09 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:12 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:14 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:17 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:19 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:23 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:22 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:25 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:28 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:31 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:33 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:36 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:39 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:42 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:44 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:47 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:49 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:50 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:52 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:55 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:41:58 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:01 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:04 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:06 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:09 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:11 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:14 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:17 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:17 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:19 WARN DAGScheduler: Broadcasting large task binary with size 3.2 MiB
# 25/04/20 20:42:22 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:25 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:27 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:30 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:33 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:35 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:38 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:41 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:43 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:44 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:47 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:49 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:52 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:54 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:42:57 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:00 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:02 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:05 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:07 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:10 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:12 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:12 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:15 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:18 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:20 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:23 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:25 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:28 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:30 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:33 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:35 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:38 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:38 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:41 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:44 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:49 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:51 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:54 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:57 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:43:59 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:02 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:05 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:07 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:08 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:10 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:13 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:15 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:18 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:20 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# 25/04/20 20:44:23 WARN DAGScheduler: Broadcasting large task binary with size 3.3 MiB
# Saving Gradient-Boosted Trees model to HDFS at: hdfs://namenode:9000/user/root/model/fraud_detection/YYYY=2025/MM=04/DD=20/gradient-boosted_trees
# Model successfully saved!
# [Stage 2027:=================================================>      (7 + 1) / 8]
# Model metadata saved to: hdfs://namenode:9000/user/root/model/fraud_detection/YYYY=2025/MM=04/DD=20/gradient-boosted_trees_metadata
